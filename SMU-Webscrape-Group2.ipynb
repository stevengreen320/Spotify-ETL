# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests
from time import sleep
import datetime as dt

# %%
from splinter import Browser
from webdriver_manager.chrome import ChromeDriverManager

# %%
from sqlalchemy import create_engine

# %%
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 93.0.4577
# Get LATEST driver version for 93.0.4577
# Get LATEST driver version for 93.0.4577
# Trying to download new driver from https://chromedriver.storage.googleapis.com/93.0.4577.63/chromedriver_win32.zip
# Driver has been saved in cache [C:\Users\Greyson\.wdm\drivers\chromedriver\win32\93.0.4577.63]

# %%
base = dt.date(2021, 9, 3)
end_list = [base - dt.timedelta(days=7*x) for x in range(5)]
end_list
# Out:
# [datetime.date(2021, 9, 3),
#  datetime.date(2021, 8, 27),
#  datetime.date(2021, 8, 20),
#  datetime.date(2021, 8, 13),
#  datetime.date(2021, 8, 6)]

# %%
base = dt.date(2021, 8, 27)
start_list = [base - dt.timedelta(days=7*x) for x in range(5)]
start_list
# Out:
# [datetime.date(2021, 8, 27),
#  datetime.date(2021, 8, 20),
#  datetime.date(2021, 8, 13),
#  datetime.date(2021, 8, 6),
#  datetime.date(2021, 7, 30)]

# %%
urls = []
countriesList = ["global","us","th","in","br","mx","jp","ph","eg","vn","tr"]
for i in range(len(countriesList)):   
    for j in range(5):
        start_date = start_list[j].strftime("%Y-%m-%d")
        end_date = end_list[j].strftime("%Y-%m-%d")
        url = f"https://spotifycharts.com/regional/{countriesList[i]}/weekly/{start_date}--{end_date}"
        urls.append(url)
urls
# Out:
# ['https://spotifycharts.com/regional/global/weekly/2021-08-27--2021-09-03',
#  'https://spotifycharts.com/regional/global/weekly/2021-08-20--2021-08-27',
#  'https://spotifycharts.com/regional/global/weekly/2021-08-13--2021-08-20',
#  'https://spotifycharts.com/regional/global/weekly/2021-08-06--2021-08-13',
#  'https://spotifycharts.com/regional/global/weekly/2021-07-30--2021-08-06',
#  'https://spotifycharts.com/regional/us/weekly/2021-08-27--2021-09-03',
#  'https://spotifycharts.com/regional/us/weekly/2021-08-20--2021-08-27',
#  'https://spotifycharts.com/regional/us/weekly/2021-08-13--2021-08-20',
#  'https://spotifycharts.com/regional/us/weekly/2021-08-06--2021-08-13',
#  'https://spotifycharts.com/regional/us/weekly/2021-07-30--2021-08-06',
#  'https://spotifycharts.com/regional/th/weekly/2021-08-27--2021-09-03',
#  'https://spotifycharts.com/regional/th/weekly/2021-08-20--2021-08-27',
#  'https://spotifycharts.com/regional/th/weekly/2021-08-13--2021-08-20',
#  'https://spotifycharts.com/regional/th/weekly/2021-08-06--2021-08-13',
#  'https://spotifycharts.com/regional/th/weekly/2021-07-30--2021-08-06',
#  'https://spotifycharts.com/regional/in/weekly/2021-08-27--2021-09-03',
#  'https://spotifycharts.com/regional/in/weekly/2021-08-20--2021-08-27',
#  'https://spotifycharts.com/regional/in/weekly/2021-08-13--2021-08-20',
#  'https://spotifycharts.com/regional/in/weekly/2021-08-06--2021-08-13',
#  'https://spotifycharts.com/regional/in/weekly/2021-07-30--2021-08-06',
#  'https://spotifycharts.com/regional/br/weekly/2021-08-27--2021-09-03',
#  'https://spotifycharts.com/regional/br/weekly/2021-08-20--2021-08-27',
#  'https://spotifycharts.com/regional/br/weekly/2021-08-13--2021-08-20',
#  'https://spotifycharts.com/regional/br/weekly/2021-08-06--2021-08-13',
#  'https://spotifycharts.com/regional/br/weekly/2021-07-30--2021-08-06',
#  'https://spotifycharts.com/regional/mx/weekly/2021-08-27--2021-09-03',
#  'https://spotifycharts.com/regional/mx/weekly/2021-08-20--2021-08-27',
#  'https://spotifycharts.com/regional/mx/weekly/2021-08-13--2021-08-20',
#  'https://spotifycharts.com/regional/mx/weekly/2021-08-06--2021-08-13',
#  'https://spotifycharts.com/regional/mx/weekly/2021-07-30--2021-08-06',
#  'https://spotifycharts.com/regional/jp/weekly/2021-08-27--2021-09-03',
#  'https://spotifycharts.com/regional/jp/weekly/2021-08-20--2021-08-27',
#  'https://spotifycharts.com/regional/jp/weekly/2021-08-13--2021-08-20',
#  'https://spotifycharts.com/regional/jp/weekly/2021-08-06--2021-08-13',
#  'https://spotifycharts.com/regional/jp/weekly/2021-07-30--2021-08-06',
#  'https://spotifycharts.com/regional/ph/weekly/2021-08-27--2021-09-03',
#  'https://spotifycharts.com/regional/ph/weekly/2021-08-20--2021-08-27',
#  'https://spotifycharts.com/regional/ph/weekly/2021-08-13--2021-08-20',
#  'https://spotifycharts.com/regional/ph/weekly/2021-08-06--2021-08-13',
#  'https://spotifycharts.com/regional/ph/weekly/2021-07-30--2021-08-06',
#  'https://spotifycharts.com/regional/eg/weekly/2021-08-27--2021-09-03',
#  'https://spotifycharts.com/regional/eg/weekly/2021-08-20--2021-08-27',
#  'https://spotifycharts.com/regional/eg/weekly/2021-08-13--2021-08-20',
#  'https://spotifycharts.com/regional/eg/weekly/2021-08-06--2021-08-13',
#  'https://spotifycharts.com/regional/eg/weekly/2021-07-30--2021-08-06',
#  'https://spotifycharts.com/regional/vn/weekly/2021-08-27--2021-09-03',
#  'https://spotifycharts.com/regional/vn/weekly/2021-08-20--2021-08-27',
#  'https://spotifycharts.com/regional/vn/weekly/2021-08-13--2021-08-20',
#  'https://spotifycharts.com/regional/vn/weekly/2021-08-06--2021-08-13',
#  'https://spotifycharts.com/regional/vn/weekly/2021-07-30--2021-08-06',
#  'https://spotifycharts.com/regional/tr/weekly/2021-08-27--2021-09-03',
#  'https://spotifycharts.com/regional/tr/weekly/2021-08-20--2021-08-27',
#  'https://spotifycharts.com/regional/tr/weekly/2021-08-13--2021-08-20',
#  'https://spotifycharts.com/regional/tr/weekly/2021-08-06--2021-08-13',
#  'https://spotifycharts.com/regional/tr/weekly/2021-07-30--2021-08-06']

# %%
artists = []
titles = []
streamCounts = []
dates = []
countryList = []
ranks = []
for u in urls:
    browser.visit(u)
    html = browser.html
    soup= BeautifulSoup(html, "lxml")
    songs= soup.find("table", {"class":"chart-table"})
    start = u.find("regional/") + len("regional/")
    end = u.find("/weekly")
    country = u[start:end]
    
    for tr in songs.find("tbody").find_all("tr"):
        rank = tr.find("td",{"class":"chart-table-position"}).text
        artist = tr.find("td", {"class": "chart-table-track"}).find("span").text
        artist= artist.replace("by ","").strip()
        title= tr.find("td",{"class": "chart-table-track"}).find("strong").text
        streamCount= tr.find("td", {"class": "chart-table-streams"}).text
        dateTemp = u.split("weekly/")[1]
        date = dateTemp.split("--")[1]
        ranks.append(rank)
        artists.append(artist)
        titles.append(title)
        streamCounts.append(streamCount)
        dates.append(date)
        countryList.append(country)
        
        

browser.quit()

# %%
#streamCountsNew = streamCounts[int(string.replace(',', '')) for x in range(len(streamCounts))]
for x in range(len(streamCounts)):
    temp = int(streamCounts[x].replace(',',''))
    streamCounts[x] = temp
    
dict_df = {
    "rank":ranks,
    "title":titles,
    "artist":artists,
    "streams":streamCounts,
    "country":countryList,
    "date":dates  
}

# %%
global_df = pd.DataFrame(dict_df)

# %%
global_df
# Out:
#       rank                              title  \
# 0        1          STAY (with Justin Bieber)
# 1        2  INDUSTRY BABY (feat. Jack Harlow)
# 2        3                         Bad Habits
# 3        4                            Beggin'
# 4        5                          Hurricane
# ...    ...                                ...
# 10995  196                          Küçücüğüm
# 10996  197                              Siyah
# 10997  198                     Seni Buldum Ya
# 10998  199          STAY (with Justin Bieber)
# 10999  200                          Glock 2.0
#
#                                                   artist   streams country  \
# 0                                          The Kid LAROI  68764542  global
# 1                                              Lil Nas X  43663527  global
# 2                                             Ed Sheeran  34182580  global
# 3                                               Måneskin  32620597  global
# 4                                             Kanye West  30609671  global
# ...                                                  ...       ...     ...
# 10995                                              Yalın    203594      tr
# 10996                              Patron, Sagopa Kajmer    201982      tr
# 10997                                        Kaan Boşnak    201945      tr
# 10998                                      The Kid LAROI    201409      tr
# 10999  cakal, Reckol, Furkan Karakılıç, Yung Ouzo, TE...    201212      tr
#
#              date
# 0      2021-09-03
# 1      2021-09-03
# 2      2021-09-03
# 3      2021-09-03
# 4      2021-09-03
# ...           ...
# 10995  2021-08-06
# 10996  2021-08-06
# 10997  2021-08-06
# 10998  2021-08-06
# 10999  2021-08-06
#
# [11000 rows x 6 columns]

# %%
base_viral = dt.date(2021, 9, 2)
viral_dates = [base_viral - dt.timedelta(days=7*x) for x in range(5)]
viral_dates
# Out:
# [datetime.date(2021, 9, 2),
#  datetime.date(2021, 8, 26),
#  datetime.date(2021, 8, 19),
#  datetime.date(2021, 8, 12),
#  datetime.date(2021, 8, 5)]

# %%
#Viral 50
urlsViral = []
countriesList = ["global","us","th","in","br","mx","jp","ph","eg","vn","tr"]
for i in range(len(countriesList)):   
    for j in range(5):
        viral_date = viral_dates[j].strftime("%Y-%m-%d")
        #end_date = end_list[j].strftime("%Y-%m-%d")
        url = f"https://spotifycharts.com/viral/{countriesList[i]}/weekly/{viral_date}--{viral_date}"
        urlsViral.append(url)
len(urlsViral)
# Out:
# 55

# %%
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 93.0.4577
# Get LATEST driver version for 93.0.4577
# Driver [C:\Users\Greyson\.wdm\drivers\chromedriver\win32\93.0.4577.63\chromedriver.exe] found in cache

# %%
artists = []
titles = []
dates = []
countryList = []
ranks = []
for u in urlsViral:
    browser.visit(u)
    html = browser.html
    soup= BeautifulSoup(html, "lxml")
    songs= soup.find("table", {"class":"chart-table"})
    start = u.find("viral/") + len("viral/")
    end = u.find("/weekly")
    country = u[start:end]
    
    for tr in songs.find("tbody").find_all("tr"):
        rank = tr.find("td",{"class":"chart-table-position"}).text
        artist = tr.find("td", {"class": "chart-table-track"}).find("span").text
        artist= artist.replace("by ","").strip()
        title= tr.find("td",{"class": "chart-table-track"}).find("strong").text
        dateTemp = u.split("weekly/")[1]
        date = dateTemp.split("--")[1]
        ranks.append(rank)
        artists.append(artist)
        titles.append(title)
        dates.append(date)
        countryList.append(country)
browser.quit()

# %%
viral_dict = {
    "rank":ranks,
    "title":titles,
    "artist":artists,
    "country":countryList,
    "date":dates  
}

# %%
viral_df = pd.DataFrame(viral_dict)
viral_df
# Out:
#      rank                          title  \
# 0       1  It's Only Me - Studio Version
# 1       2        Chega E Senta - Ao Vivo
# 2       3              Manike Mage Hithe
# 3       4                     Now I Know
# 4       5             Passinho Debochado
# ...   ...                            ...
# 2745   46                     Ölebilirim
# 2746   47                          Bingo
# 2747   48                  Anıları Sakla
# 2748   49            Flashbacks (Slowed)
# 2749   50                  Ara Beni Cano
#
#                                     artist country        date
# 0                                  Kaleb J  global  2021-09-02
# 1                         John Amplificado  global  2021-09-02
# 2     Chamath Sangeeth, Yohani, Satheeshan  global  2021-09-02
# 3                                  Kaleb J  global  2021-09-02
# 4                              Dan Ventura  global  2021-09-02
# ...                                    ...     ...         ...
# 2745                          Bedo, Patron      tr  2021-08-05
# 2746                              Organize      tr  2021-08-05
# 2747                        Batuhan Kordel      tr  2021-08-05
# 2748                              CRASPORE      tr  2021-08-05
# 2749                           Uro58, Grow      tr  2021-08-05
#
# [2750 rows x 5 columns]

# %%
country_dict = {"country":countriesList}
country_df = pd.DataFrame(country_dict)

# %%
country_df
# Out:
#    country
# 0   global
# 1       us
# 2       th
# 3       in
# 4       br
# 5       mx
# 6       jp
# 7       ph
# 8       eg
# 9       vn
# 10      tr

# %%
viral_artist_unique = viral_df.artist.unique()
viral_artist_dict = {"artist":viral_artist_unique}
viral_artist_df = pd.DataFrame(viral_artist_dict)
viral_artist_df
# Out:
#                                    artist
# 0                                 Kaleb J
# 1                        John Amplificado
# 2    Chamath Sangeeth, Yohani, Satheeshan
# 3                             Dan Ventura
# 4                                  A-Wall
# ..                                    ...
# 705                              Lvbel C5
# 706                          Bedo, Patron
# 707                              Organize
# 708                              CRASPORE
# 709                           Uro58, Grow
#
# [710 rows x 1 columns]

# %%
artist_unique = global_df.artist.unique()
artist_dict = {"artist":artist_unique}
artist_df = pd.DataFrame(artist_dict)
artist_df
# Out:
#                                                  artist
# 0                                         The Kid LAROI
# 1                                             Lil Nas X
# 2                                            Ed Sheeran
# 3                                              Måneskin
# 4                                            Kanye West
# ...                                                 ...
# 1328                                             Stabil
# 1329                                              Hidra
# 1330                                        Irmak Arıcı
# 1331                              Patron, Sagopa Kajmer
# 1332  cakal, Reckol, Furkan Karakılıç, Yung Ouzo, TE...
#
# [1333 rows x 1 columns]

# %%
artist_temp_df = pd.concat([artist_df,viral_artist_df]).drop_duplicates().reset_index(drop=True)

# %%
rds_connection_string = "postgres:booth@35.223.88.224:5432/Spotify"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
artist_temp_df.to_sql(name='artist', con=engine, if_exists='append', index=False)

# %%
new_artist_df = pd.read_sql_query('select * from artist', con=engine)

# %%
country_df.to_sql(name='country', con=engine, if_exists='append', index=False)

# %%
new_country_df = pd.read_sql_query('select * from country', con=engine) 
new_country_df
# Out:
#     country_id country               last_updated
# 0            1  global 2021-09-14 17:50:21.736975
# 1            2      us 2021-09-14 17:50:21.736975
# 2            3      th 2021-09-14 17:50:21.736975
# 3            4      in 2021-09-14 17:50:21.736975
# 4            5      br 2021-09-14 17:50:21.736975
# 5            6      mx 2021-09-14 17:50:21.736975
# 6            7      jp 2021-09-14 17:50:21.736975
# 7            8      ph 2021-09-14 17:50:21.736975
# 8            9      eg 2021-09-14 17:50:21.736975
# 9           10      vn 2021-09-14 17:50:21.736975
# 10          11      tr 2021-09-14 17:50:21.736975

# %%
sub1 = global_df.merge(new_country_df,how="left",on="country")
sub2 = sub1.drop("country",1)
sub2
# Out:
#       rank                              title  \
# 0        1          STAY (with Justin Bieber)
# 1        2  INDUSTRY BABY (feat. Jack Harlow)
# 2        3                         Bad Habits
# 3        4                            Beggin'
# 4        5                          Hurricane
# ...    ...                                ...
# 10995  196                          Küçücüğüm
# 10996  197                              Siyah
# 10997  198                     Seni Buldum Ya
# 10998  199          STAY (with Justin Bieber)
# 10999  200                          Glock 2.0
#
#                                                   artist   streams  \
# 0                                          The Kid LAROI  68764542
# 1                                              Lil Nas X  43663527
# 2                                             Ed Sheeran  34182580
# 3                                               Måneskin  32620597
# 4                                             Kanye West  30609671
# ...                                                  ...       ...
# 10995                                              Yalın    203594
# 10996                              Patron, Sagopa Kajmer    201982
# 10997                                        Kaan Boşnak    201945
# 10998                                      The Kid LAROI    201409
# 10999  cakal, Reckol, Furkan Karakılıç, Yung Ouzo, TE...    201212
#
#              date  country_id               last_updated
# 0      2021-09-03           1 2021-09-14 17:50:21.736975
# 1      2021-09-03           1 2021-09-14 17:50:21.736975
# 2      2021-09-03           1 2021-09-14 17:50:21.736975
# 3      2021-09-03           1 2021-09-14 17:50:21.736975
# 4      2021-09-03           1 2021-09-14 17:50:21.736975
# ...           ...         ...                        ...
# 10995  2021-08-06          11 2021-09-14 17:50:21.736975
# 10996  2021-08-06          11 2021-09-14 17:50:21.736975
# 10997  2021-08-06          11 2021-09-14 17:50:21.736975
# 10998  2021-08-06          11 2021-09-14 17:50:21.736975
# 10999  2021-08-06          11 2021-09-14 17:50:21.736975
#
# [11000 rows x 7 columns]

# %%
sub3 = sub2.merge(new_artist_df,how="left",on="artist")
sub4 = sub3.drop("artist",1)
sub5 = sub4.drop("last_updated_y",1)
sub6 =sub5.rename(columns={"last_updated_x":"last_updated"})
final_global_df = sub6
final_global_df
# Out:
#       rank                              title   streams        date  \
# 0        1          STAY (with Justin Bieber)  68764542  2021-09-03
# 1        2  INDUSTRY BABY (feat. Jack Harlow)  43663527  2021-09-03
# 2        3                         Bad Habits  34182580  2021-09-03
# 3        4                            Beggin'  32620597  2021-09-03
# 4        5                          Hurricane  30609671  2021-09-03
# ...    ...                                ...       ...         ...
# 10995  196                          Küçücüğüm    203594  2021-08-06
# 10996  197                              Siyah    201982  2021-08-06
# 10997  198                     Seni Buldum Ya    201945  2021-08-06
# 10998  199          STAY (with Justin Bieber)    201409  2021-08-06
# 10999  200                          Glock 2.0    201212  2021-08-06
#
#        country_id               last_updated  artist_id
# 0               1 2021-09-14 17:50:21.736975          1
# 1               1 2021-09-14 17:50:21.736975          2
# 2               1 2021-09-14 17:50:21.736975          3
# 3               1 2021-09-14 17:50:21.736975          4
# 4               1 2021-09-14 17:50:21.736975          5
# ...           ...                        ...        ...
# 10995          11 2021-09-14 17:50:21.736975       1244
# 10996          11 2021-09-14 17:50:21.736975       1332
# 10997          11 2021-09-14 17:50:21.736975       1203
# 10998          11 2021-09-14 17:50:21.736975          1
# 10999          11 2021-09-14 17:50:21.736975       1333
#
# [11000 rows x 7 columns]

# %%
final_global_df.to_sql(name='Top_200', con=engine, if_exists='append', index=False)

# %%
pd.read_sql_query("""select tt.title,a.artist, c.country 
from 
    "Top_200" tt
Join 
    "country" c on
        tt.country_id = c.country_id
join artist a on
    tt.artist_id = a.artist_id;
""", con=engine)
# Out:
#                                    title  \
# 0              STAY (with Justin Bieber)
# 1      INDUSTRY BABY (feat. Jack Harlow)
# 2                             Bad Habits
# 3                                Beggin'
# 4                              Hurricane
# ...                                  ...
# 10995                          Küçücüğüm
# 10996                              Siyah
# 10997                     Seni Buldum Ya
# 10998          STAY (with Justin Bieber)
# 10999                          Glock 2.0
#
#                                                   artist country
# 0                                          The Kid LAROI  global
# 1                                              Lil Nas X  global
# 2                                             Ed Sheeran  global
# 3                                               Måneskin  global
# 4                                             Kanye West  global
# ...                                                  ...     ...
# 10995                                              Yalın      tr
# 10996                              Patron, Sagopa Kajmer      tr
# 10997                                        Kaan Boşnak      tr
# 10998                                      The Kid LAROI      tr
# 10999  cakal, Reckol, Furkan Karakılıç, Yung Ouzo, TE...      tr
#
# [11000 rows x 3 columns]

# %%
sub1 = viral_df.merge(new_country_df,how="left",on="country")
sub2 = sub1.drop("country",1)
sub2
# Out:
#      rank                          title  \
# 0       1  It's Only Me - Studio Version
# 1       2        Chega E Senta - Ao Vivo
# 2       3              Manike Mage Hithe
# 3       4                     Now I Know
# 4       5             Passinho Debochado
# ...   ...                            ...
# 2745   46                     Ölebilirim
# 2746   47                          Bingo
# 2747   48                  Anıları Sakla
# 2748   49            Flashbacks (Slowed)
# 2749   50                  Ara Beni Cano
#
#                                     artist        date  country_id  \
# 0                                  Kaleb J  2021-09-02           1
# 1                         John Amplificado  2021-09-02           1
# 2     Chamath Sangeeth, Yohani, Satheeshan  2021-09-02           1
# 3                                  Kaleb J  2021-09-02           1
# 4                              Dan Ventura  2021-09-02           1
# ...                                    ...         ...         ...
# 2745                          Bedo, Patron  2021-08-05          11
# 2746                              Organize  2021-08-05          11
# 2747                        Batuhan Kordel  2021-08-05          11
# 2748                              CRASPORE  2021-08-05          11
# 2749                           Uro58, Grow  2021-08-05          11
#
#                    last_updated
# 0    2021-09-14 17:50:21.736975
# 1    2021-09-14 17:50:21.736975
# 2    2021-09-14 17:50:21.736975
# 3    2021-09-14 17:50:21.736975
# 4    2021-09-14 17:50:21.736975
# ...                         ...
# 2745 2021-09-14 17:50:21.736975
# 2746 2021-09-14 17:50:21.736975
# 2747 2021-09-14 17:50:21.736975
# 2748 2021-09-14 17:50:21.736975
# 2749 2021-09-14 17:50:21.736975
#
# [2750 rows x 6 columns]

# %%
sub3 = sub2.merge(new_artist_df,how="left",on="artist")
sub4 = sub3.drop("artist",1)
sub5 = sub4.drop("last_updated_y",1)
sub6 =sub5.rename(columns={"last_updated_x":"last_updated"})
final_viral_df = sub6
final_viral_df
# Out:
#      rank                          title        date  country_id  \
# 0       1  It's Only Me - Studio Version  2021-09-02           1
# 1       2        Chega E Senta - Ao Vivo  2021-09-02           1
# 2       3              Manike Mage Hithe  2021-09-02           1
# 3       4                     Now I Know  2021-09-02           1
# 4       5             Passinho Debochado  2021-09-02           1
# ...   ...                            ...         ...         ...
# 2745   46                     Ölebilirim  2021-08-05          11
# 2746   47                          Bingo  2021-08-05          11
# 2747   48                  Anıları Sakla  2021-08-05          11
# 2748   49            Flashbacks (Slowed)  2021-08-05          11
# 2749   50                  Ara Beni Cano  2021-08-05          11
#
#                    last_updated  artist_id
# 0    2021-09-14 17:50:21.736975       1334
# 1    2021-09-14 17:50:21.736975         57
# 2    2021-09-14 17:50:21.736975        395
# 3    2021-09-14 17:50:21.736975       1334
# 4    2021-09-14 17:50:21.736975        568
# ...                         ...        ...
# 2745 2021-09-14 17:50:21.736975       1187
# 2746 2021-09-14 17:50:21.736975       1221
# 2747 2021-09-14 17:50:21.736975       1213
# 2748 2021-09-14 17:50:21.736975       1761
# 2749 2021-09-14 17:50:21.736975       1762
#
# [2750 rows x 6 columns]

# %%
final_viral_df.to_sql(name='Viral_50', con=engine, if_exists='append', index=False)

# %%
pd.read_sql_query("""select vf.title,a.artist, c.country 
from 
    "Viral_50" vf
Join 
    "country" c on
        vf.country_id = c.country_id
join artist a on
    vf.artist_id = a.artist_id;
""", con=engine)
# Out:
#                               title                                artist  \
# 0     It's Only Me - Studio Version                               Kaleb J
# 1           Chega E Senta - Ao Vivo                      John Amplificado
# 2                 Manike Mage Hithe  Chamath Sangeeth, Yohani, Satheeshan
# 3                        Now I Know                               Kaleb J
# 4                Passinho Debochado                           Dan Ventura
# ...                             ...                                   ...
# 2745                     Ölebilirim                          Bedo, Patron
# 2746                          Bingo                              Organize
# 2747                  Anıları Sakla                        Batuhan Kordel
# 2748            Flashbacks (Slowed)                              CRASPORE
# 2749                  Ara Beni Cano                           Uro58, Grow
#
#      country
# 0     global
# 1     global
# 2     global
# 3     global
# 4     global
# ...      ...
# 2745      tr
# 2746      tr
# 2747      tr
# 2748      tr
# 2749      tr
#
# [2750 rows x 3 columns]
